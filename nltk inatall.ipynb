# %%
import os
import nltk

print(os.getcwd())
nltk.download()
# Out:
# C:\Users\SHUBHAM
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
import nltk
from nltk.tokenize import word_tokenize

text='hello shubham , welcome to nltk'
print(word_tokenize(text))
# Out:
# ['hello', 'shubham', ',', 'welcome', 'to', 'nltk']
